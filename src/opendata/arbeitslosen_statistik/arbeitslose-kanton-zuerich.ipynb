# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Autogenerated Python starter code for data set with identifier* **318@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]**

# %% [markdown]
# ## Description
#
# Anteil Arbeitslose an der zivilrechtlichen Wohnbevölkerung zwischen 15 und 64 Jahren. Aus Datenschutzgründen dürfen Quoten von Gemeinden mit weniger als 5 Arbeitslosen (Jahresmittel) nicht ausgewiesen werden.

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/statistik-daten/datenkatalog.html#/datasets/318@statistisches-amt-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2016-01-20T20:16:00`
# - **Modified** `2024-03-04T13:59:08`
# - **Startdate** `2011-12-31`
# - **Enddate** `2023-12-31`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/ECON']`
# - **Keyword** `['arbeitslose', 'arbeitslosigkeit', 'arbeitsmarkt', 'bezirke', 'gemeinden', 'kanton_zuerich', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/gemeinden/gemeindeportraet.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.style.use("ggplot")

params = {
    "text.color": (0.25, 0.25, 0.25),
    "figure.figsize": [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines="warn", encoding_errors="ignore", low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=";", on_bad_lines="warn", encoding_errors="ignore", low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 243
# Title                    : Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]
# Description              : None
# Issued                   : 2016-01-21T16:30:35
# Modified                 : 2024-03-04T13:59:08

df = get_dataset("https://www.web.statistik.zh.ch/ogd/data/KANTON_ZUERICH_380.csv")

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how="all", axis=1, inplace=True)

# %%
print(f"The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).")
print(f"There seem to be {df.duplicated().sum()} exact duplicates in the data.")
# Out:
# The dataset has 2,662 rows (observations) and 11 columns (variables).
# There seem to be 0 exact duplicates in the data.

# %%
df.info(memory_usage="deep", verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2662 entries, 0 to 2661
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BFS_NR           2662 non-null   int64
#  1   GEBIET_NAME      2662 non-null   object
#  2   THEMA_NAME       2662 non-null   object
#  3   SET_NAME         2662 non-null   object
#  4   SUBSET_NAME      2662 non-null   object
#  5   INDIKATOR_ID     2662 non-null   int64
#  6   INDIKATOR_NAME   2662 non-null   object
#  7   INDIKATOR_JAHR   2662 non-null   int64
#  8   INDIKATOR_VALUE  2471 non-null   float64
#  9   EINHEIT_KURZ     2662 non-null   object
#  10  EINHEIT_LANG     2662 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.4 MB

# %%
df.head()
# Out:
#    BFS_NR  GEBIET_NAME              THEMA_NAME          SET_NAME  \
# 0       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 1       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 2       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 3       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# 4       1  Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
#
#         SUBSET_NAME  INDIKATOR_ID  \
# 0  Arbeitslosigkeit           380
# 1  Arbeitslosigkeit           380
# 2  Arbeitslosigkeit           380
# 3  Arbeitslosigkeit           380
# 4  Arbeitslosigkeit           380
#
#                                       INDIKATOR_NAME  INDIKATOR_JAHR  \
# 0  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2011
# 1  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2012
# 2  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2013
# 3  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2014
# 4  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]            2015
#
#    INDIKATOR_VALUE EINHEIT_KURZ EINHEIT_LANG
# 0              1.4            %      Prozent
# 1              1.3            %      Prozent
# 2              1.8            %      Prozent
# 3              1.3            %      Prozent
# 4              1.8            %      Prozent

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T
# Out:
#                                                               164   \
# BFS_NR                                                          12
# GEBIET_NAME                                             Rifferswil
# THEMA_NAME                                  Arbeit und Unternehmen
# SET_NAME                                          Arbeitslosigkeit
# SUBSET_NAME                                       Arbeitslosigkeit
# INDIKATOR_ID                                                   380
# INDIKATOR_NAME   Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]
# INDIKATOR_JAHR                                                2021
# INDIKATOR_VALUE                                                0.9
# EINHEIT_KURZ                                                     %
# EINHEIT_LANG                                               Prozent
#
#                                                               42    \
# BFS_NR                                                           4
# GEBIET_NAME                                            Hausen a.A.
# THEMA_NAME                                  Arbeit und Unternehmen
# SET_NAME                                          Arbeitslosigkeit
# SUBSET_NAME                                       Arbeitslosigkeit
# INDIKATOR_ID                                                   380
# INDIKATOR_NAME   Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]
# INDIKATOR_JAHR                                                2011
# INDIKATOR_VALUE                                                1.3
# EINHEIT_KURZ                                                     %
# EINHEIT_LANG                                               Prozent
#
#                                                               2230
# BFS_NR                                                         251
# GEBIET_NAME                                              Weiningen
# THEMA_NAME                                  Arbeit und Unternehmen
# SET_NAME                                          Arbeitslosigkeit
# SUBSET_NAME                                       Arbeitslosigkeit
# INDIKATOR_ID                                                   380
# INDIKATOR_NAME   Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]
# INDIKATOR_JAHR                                                2013
# INDIKATOR_VALUE                                                3.3
# EINHEIT_KURZ                                                     %
# EINHEIT_LANG                                               Prozent

# %%
# describe non-numerical features
try:
    with pd.option_context("display.float_format", "{:,.2f}".format):
        display(df.describe(exclude="number"))
except:
    print("No categorical data in dataset.")
# Out:
#         GEBIET_NAME              THEMA_NAME          SET_NAME  \
# count          2662                    2662              2662
# unique          201                       1                 1
# top     Aeugst a.A.  Arbeit und Unternehmen  Arbeitslosigkeit
# freq             14                    2662              2662
#
#              SUBSET_NAME                                     INDIKATOR_NAME  \
# count               2662                                               2662
# unique                 1                                                  1
# top     Arbeitslosigkeit  Arbeitslosenanteil an Bevölkerung 15-64 Jahre [%]
# freq                2662                                               2662
#
#        EINHEIT_KURZ EINHEIT_LANG
# count          2662         2662
# unique            1            1
# top               %      Prozent
# freq           2662         2662

# %%
# describe numerical features
try:
    with pd.option_context("display.float_format", "{:,.2f}".format):
        display(df.describe(include="number"))
except:
    print("No numercial data in dataset.")
# Out:
#         BFS_NR  INDIKATOR_ID  INDIKATOR_JAHR  INDIKATOR_VALUE
# count 2,662.00      2,662.00        2,662.00         2,471.00
# mean    107.84        380.00        2,017.41             1.92
# std      85.85          0.00            4.03             0.69
# min       0.00        380.00        2,011.00             0.60
# 25%      30.00        380.00        2,014.00             1.40
# 50%      93.00        380.00        2,017.00             1.80
# 75%     180.00        380.00        2,021.00             2.40
# max     298.00        380.00        2,024.00             4.90

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno

msno.matrix(df, labels=True, sort="descending");
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 3
#       1 # check missing values with missingno
#       2 # https://github.com/ResidentMario/missingno
# ----> 3 import missingno as msno
#       5 msno.matrix(df, labels=True, sort="descending");
#
# ModuleNotFoundError: No module named 'missingno'

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Statistisches Amt des Kantons Zürich | Data Shop | datashop@statistik.zh.ch
